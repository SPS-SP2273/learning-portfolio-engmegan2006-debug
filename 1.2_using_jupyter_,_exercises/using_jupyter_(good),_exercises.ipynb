# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# Hello World

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
# Kernel was restarted using Restart button above 
# Jupyter Kernel is hence restarted

# %%
squares = [i**2 for i in range(10)]
print(squares)
# %%timeit

# print n^2 list [], for a list of 10 consecutive i starting from i=0
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# UsageError: Line magic function `%%timeit` not found.

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# %%timeit
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# UsageError: Line magic function `%%timeit` not found.

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# %timeit
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = [i**2 for i in range(10)]
print(squares)
# %timeit
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit -n 5000
squares = [i**2 for i in range(10)]
print(squares)          # edit the syntax: decrease the number of loops (by adding '-n 5000') instead of interrupting the code
                        # an end will be reached earlier, can time the process
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ...

# %%
# %%timeit -n 5000
squares = list()
for i in range(10):
    squares.append(i**2)

# if include print(squares), the nightmare print will just repeat :(
# include '-n 5000' to shorten the number of repeats, to shorten the time taken
# Out:
# 1.14 μs ± 48.8 ns per loop (mean ± std. dev. of 7 runs, 5,000 loops each)
